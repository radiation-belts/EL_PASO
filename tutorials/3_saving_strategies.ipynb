# %% [markdown]
# # Tutorial: Saving strategies
#
# This tutorial will teach you how to save your processed variables using different *SavingStrategies*.
#
# We will use the loaded variables from the cdf file to showcase how to save them with different formats. We will add additional variables so that we have more to save.

# %%
import logging
import sys
from datetime import datetime, timezone

from astropy import units as u

import el_paso as ep

logging.basicConfig(stream=sys.stdout, level=logging.INFO)

extraction_infos = [
    ep.ExtractionInfo(
        result_key="Epoch",
        name_or_column="Epoch_Ele",
        unit=ep.units.cdf_epoch,
    ),
    ep.ExtractionInfo(
        result_key="FEDU",
        name_or_column="FEDU",
        unit=(u.cm**2 * u.s * u.sr * u.keV) ** (-1),
    ),
    ep.ExtractionInfo(
        result_key="xGEO",
        name_or_column="Position_Ele",
        unit=u.km,
    ),
]

start_time = datetime(2017, 7, 30, tzinfo=timezone.utc)
end_time = datetime(2017, 8, 1, 23, 59, 59, tzinfo=timezone.utc)

file_name_stem = "rbspa_rel04_ect-hope-pa-l3_YYYYMMDD_.{6}.cdf"

ep.download(
    start_time,
    end_time,
    save_path=".",
    download_url="https://spdf.gsfc.nasa.gov/pub/data/rbsp/rbspa/l3/ect/hope/pitchangle/rel04/YYYY/",
    file_name_stem=file_name_stem,
    file_cadence="daily",
    method="request",
    skip_existing=True,
)

variables = ep.extract_variables_from_files(
    start_time, end_time, "daily", data_path=".", file_name_stem=file_name_stem, extraction_infos=extraction_infos
)
variables
# Out:
# Logger not instantiated.
# Basic logger can be instantiated using `logging.basicConfig(level=logging.INFO)`
# INFO:el_paso.download:File already exists, skipping download: rbspa_rel04_ect-hope-pa-l3_20170730_v7.3.0.cdf
# INFO:el_paso.download:File already exists, skipping download: rbspa_rel04_ect-hope-pa-l3_20170731_v7.4.0.cdf
# INFO:el_paso.download:File already exists, skipping download: rbspa_rel04_ect-hope-pa-l3_20170801_v7.3.0.cdf
# INFO:el_paso.utils:		Finished in 0.352 seconds
# INFO:el_paso.extract_variables_from_files:Extracting variables ...
# {'Epoch': Variable holding (12474,) data points with metadata: VariableMetadata(unit=Unit("cdf_epoch"), original_cadence_seconds=0, source_files=['rbspa_rel04_ect-hope-pa-l3_20170730_v7.3.0.cdf', 'rbspa_rel04_ect-hope-pa-l3_20170731_v7.4.0.cdf', 'rbspa_rel04_ect-hope-pa-l3_20170801_v7.3.0.cdf'], description='', processing_notes='', standard_name=''),
#  'FEDU': Variable holding (12474, 11, 72) data points with metadata: VariableMetadata(unit=Unit("1 / (keV s sr cm2)"), original_cadence_seconds=0, source_files=['rbspa_rel04_ect-hope-pa-l3_20170730_v7.3.0.cdf', 'rbspa_rel04_ect-hope-pa-l3_20170731_v7.4.0.cdf', 'rbspa_rel04_ect-hope-pa-l3_20170801_v7.3.0.cdf'], description='', processing_notes='', standard_name=''),
#  'xGEO': Variable holding (12474, 3) data points with metadata: VariableMetadata(unit=Unit("km"), original_cadence_seconds=0, source_files=['rbspa_rel04_ect-hope-pa-l3_20170730_v7.3.0.cdf', 'rbspa_rel04_ect-hope-pa-l3_20170731_v7.4.0.cdf', 'rbspa_rel04_ect-hope-pa-l3_20170801_v7.3.0.cdf'], description='', processing_notes='', standard_name='')}

# %% [markdown]
# ## Single file strategy
#
# First, we want to save the variables using the *SingleFileStrategy*. This is the simplest way to save variables, as everything is simple put into one file. Dependent on the file ending, different file formats will be saved. Possible formats are ".mat", ".pickle", and ".h5".
#
# The units of the variables are not changed when using the SingleFileStrategy.

# %%
saving_strategy = ep.saving_strategies.SingleFileStrategy("rbsp_hope_example.pickle")
ep.save(
    variables, saving_strategy=saving_strategy, start_time=start_time, end_time=end_time, time_var=variables["Epoch"]
)
# Out:
# INFO:el_paso.saving_strategy:Saving file rbsp_hope_example.pickle...
# INFO:el_paso.utils:		Finished in 0.521 seconds

# %% [markdown]
# Let's inspect what got saved. The variables are turned into simple numpy arrays before saving. You can see that also a *metadata* variable has been saved. We will look closer at metadata in a different tutorial.

# %%
import pickle

with open("rbsp_hope_example.pickle", "rb") as f:
    loaded_data = pickle.load(f)
    print("Keys: ", loaded_data.keys())
    print("Metadata: ", loaded_data["metadata"])
    print("xGEO[0,:]: ", loaded_data["xGEO"][0, :] * u.Unit(loaded_data["metadata"]["xGEO"]["unit"]))
# Out:
# Keys:  dict_keys(['Epoch', 'FEDU', 'xGEO', 'metadata'])
# Metadata:  {'Epoch': {'unit': 'cdf_epoch', 'original_cadence_seconds': 0, 'source_files': ['rbspa_rel04_ect-hope-pa-l3_20170730_v7.3.0.cdf', 'rbspa_rel04_ect-hope-pa-l3_20170731_v7.4.0.cdf', 'rbspa_rel04_ect-hope-pa-l3_20170801_v7.3.0.cdf'], 'description': '', 'processing_notes': ''}, 'FEDU': {'unit': '1 / (keV s sr cm2)', 'original_cadence_seconds': 0, 'source_files': ['rbspa_rel04_ect-hope-pa-l3_20170730_v7.3.0.cdf', 'rbspa_rel04_ect-hope-pa-l3_20170731_v7.4.0.cdf', 'rbspa_rel04_ect-hope-pa-l3_20170801_v7.3.0.cdf'], 'description': '', 'processing_notes': ''}, 'xGEO': {'unit': 'km', 'original_cadence_seconds': 0, 'source_files': ['rbspa_rel04_ect-hope-pa-l3_20170730_v7.3.0.cdf', 'rbspa_rel04_ect-hope-pa-l3_20170731_v7.4.0.cdf', 'rbspa_rel04_ect-hope-pa-l3_20170801_v7.3.0.cdf'], 'description': '', 'processing_notes': ''}}
# xGEO[0,:]:  [-20312.193   -27551.27      1005.89374] km

# %% [markdown]
# ## Data-org strategy
#
# All data at GFZ is stored under a standard, which we call DataOrg (Data Organization). The standard inlcudes monthly files, where variables are split into separate files to reduce loading times. All files are saved as .mat files. By using the *DataOrgStrategy*, the variables are automatically sorted into the corresponding files, based on the key of the variable_dict. Additionally, the variables are converted into the units as described in the standard.
#
# For using it, we have to store the variables in a dictionary with certain keys, as specified by the standard.

# %%
variables_to_save = {
    "time": variables["Epoch"],
    "Flux": variables["FEDU"],
    "xGEO": variables["xGEO"],
}

saving_strategy = ep.saving_strategies.DataOrgStrategy(
    ".", mission="RBSP", satellite="rbspa", instrument="hope", kext="T89"
)
ep.save(variables_to_save, saving_strategy, start_time, end_time, time_var=variables["Epoch"])
# Out:
# INFO:el_paso.saving_strategy:Saving file rbspa_hope_20170701to20170731_flux_ver4.mat...
# WARNING:py.warnings:/home/jhawar/anaconda3/envs/verb4d/lib/python3.11/site-packages/el_paso/save.py:69: UserWarning: Could not find target variable alpha_local!
#   target_variables = saving_strategy.get_target_variables(
#
# WARNING:el_paso.save:Saving attempted, but product is missing some required variables for output alpha_and_energy!
# WARNING:py.warnings:/home/jhawar/anaconda3/envs/verb4d/lib/python3.11/site-packages/el_paso/save.py:69: UserWarning: Could not find target variable MLT!
#   target_variables = saving_strategy.get_target_variables(
#
# WARNING:el_paso.save:Saving attempted, but product is missing some required variables for output mlt!
# WARNING:py.warnings:/home/jhawar/anaconda3/envs/verb4d/lib/python3.11/site-packages/el_paso/save.py:69: UserWarning: Could not find target variable Lstar!
#   target_variables = saving_strategy.get_target_variables(
#
# WARNING:el_paso.save:Saving attempted, but product is missing some required variables for output lstar!
# WARNING:py.warnings:/home/jhawar/anaconda3/envs/verb4d/lib/python3.11/site-packages/el_paso/save.py:69: UserWarning: Could not find target variable Lm!
#   target_variables = saving_strategy.get_target_variables(
#
# WARNING:el_paso.save:Saving attempted, but product is missing some required variables for output lm!
# WARNING:py.warnings:/home/jhawar/anaconda3/envs/verb4d/lib/python3.11/site-packages/el_paso/save.py:69: UserWarning: Could not find target variable PSD!
#   target_variables = saving_strategy.get_target_variables(
#
# WARNING:el_paso.save:Saving attempted, but product is missing some required variables for output psd!
# INFO:el_paso.saving_strategy:Saving file rbspa_hope_20170701to20170731_xGEO_ver4.mat...
# WARNING:py.warnings:/home/jhawar/anaconda3/envs/verb4d/lib/python3.11/site-packages/el_paso/save.py:69: UserWarning: Could not find target variable InvMu!
#   target_variables = saving_strategy.get_target_variables(
#
# WARNING:el_paso.save:Saving attempted, but product is missing some required variables for output invmu_and_invk!
# WARNING:py.warnings:/home/jhawar/anaconda3/envs/verb4d/lib/python3.11/site-packages/el_paso/save.py:69: UserWarning: Could not find target variable B_eq!
#   target_variables = saving_strategy.get_target_variables(
#
# WARNING:el_paso.save:Saving attempted, but product is missing some required variables for output bfield!
# WARNING:py.warnings:/home/jhawar/anaconda3/envs/verb4d/lib/python3.11/site-packages/el_paso/save.py:69: UserWarning: Could not find target variable R0!
#   target_variables = saving_strategy.get_target_variables(
#
# WARNING:el_paso.save:Saving attempted, but product is missing some required variables for output R0!
# WARNING:py.warnings:/home/jhawar/anaconda3/envs/verb4d/lib/python3.11/site-packages/el_paso/save.py:69: UserWarning: Could not find target variable density!
#   target_variables = saving_strategy.get_target_variables(
#
# WARNING:el_paso.save:Saving attempted, but product is missing some required variables for output density!
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 10
#       1 variables_to_save = {
#       2     "time": variables["Epoch"],
#       3     "Flux": variables["FEDU"],
#       4     "xGEO": variables["xGEO"],
#       5 }
#       7 saving_strategy = ep.saving_strategies.DataOrgStrategy(
#       8     ".", mission="RBSP", satellite="rbspa", instrument="hope", kext="T89"
#       9 )
# ---> 10 ep.save(variables_to_save, saving_strategy, start_time, end_time, time_var=variables["Epoch"])
#
# File ~/anaconda3/envs/verb4d/lib/python3.11/site-packages/el_paso/utils.py:155, in timed_function.<locals>.timed_function_.<locals>.wrap(*args, **kwargs)
#     152 @wraps(f)
#     153 def wrap(*args: P.args, **kwargs: P.kwargs) -> R:
#     154     tic = timeit.default_timer()
# --> 155     result = f(*args, **kwargs)
#     156     toc = timeit.default_timer()
#     157     if func_name:
#
# File ~/anaconda3/envs/verb4d/lib/python3.11/site-packages/el_paso/save.py:69, in save(variables_dict, saving_strategy, start_time, end_time, time_var, append)
#      66 for output_file in saving_strategy.output_files:
#      67     file_path = saving_strategy.get_file_path(interval_start, interval_end, output_file)
# ---> 69     target_variables = saving_strategy.get_target_variables(
#      70         output_file, variables_dict, time_var, interval_start, interval_end
#      71     )
#      73     if target_variables is None:
#      74         logger.warning(
#      75             f"Saving attempted, but product is missing some required variables for output {output_file.name}!",
#      76             stacklevel=2,
#      77         )
#
# File ~/anaconda3/envs/verb4d/lib/python3.11/site-packages/el_paso/saving_strategy.py:164, in SavingStrategy.get_target_variables(self, output_file, variables_dict, time_var, start_time, end_time)
#     162     if start_time is not None and end_time is not None and time_var is not None:
#     163         var_to_save.truncate(time_var, start_time.timestamp(), end_time.timestamp())
# --> 164     var_to_save = self.standardize_variable(var_to_save, name_to_save)
#     166     target_variables[name_to_save] = var_to_save
#     167 else:
#
# File ~/anaconda3/envs/verb4d/lib/python3.11/site-packages/el_paso/saving_strategies/data_org_strategy.py:123, in DataOrgStrategy.standardize_variable(self, variable, name_in_file)
#     105 def standardize_variable(self, variable: Variable, name_in_file: str) -> Variable:
#     106     """Standardizes a variable's units and dimensions based on its predefined name.
#     107
#     108     This method acts as a proxy, delegating the actual standardization logic
#    (...)    121         ValueError: If an unknown `name_in_file` is encountered..
#     122     """
# --> 123     return self.data_standard.standardize_variable(name_in_file, variable)
#
# File ~/anaconda3/envs/verb4d/lib/python3.11/site-packages/el_paso/data_standards/data_org_standard.py:51, in DataOrgStandard.standardize_variable(self, standard_name, variable)
#      49 assert_n_dim(variable, 3, standard_name)
#      50 shape = variable.get_data().shape
# ---> 51 self.consistency_check.check_time_size(shape[0], standard_name)
#      52 self.consistency_check.check_energy_size(shape[1], standard_name)
#      53 self.consistency_check.check_pitch_angle_size(shape[2], standard_name)
#
# File ~/anaconda3/envs/verb4d/lib/python3.11/site-packages/el_paso/data_standard.py:80, in ConsistencyCheck.check_time_size(self, provided_len_time, name_in_file)
#      75 elif self.len_time.size != provided_len_time:
#      76     msg = (
#      77         f"Time length mismatch! Time length of variable {self.len_time.name}: {self.len_time.size}",
#      78         f"and of variable {name_in_file}: {provided_len_time}",
#      79     )
# ---> 80     raise ValueError(msg)
#
# ValueError: ('Time length mismatch! Time length of variable Flux: 8292', 'and of variable Flux: 4182')

# %% [markdown]
# Let's inspect again, what has been saved. Flux-files and xGEO-files got saved. Note how the metadata struct is again saved and that the units of xGEO got automatically transformed from km to R_E.

# %%
from pathlib import Path
from scipy.io import loadmat

saved_files = sorted(Path("RBSP/rbspa/Processed_Mat_Files").glob("*.mat"))
print("Number of saved files:", len(saved_files))
print("Saved files:", saved_files)

xGEO_data = loadmat(saved_files[1], simplify_cells=True)

print("xGEO data keys:", xGEO_data.keys())
print("xGEO data metadata:", xGEO_data["metadata"]["xGEO"].keys())
print("xGEO[0,:]:", xGEO_data["xGEO"][0, :] * u.Unit(xGEO_data["metadata"]["xGEO"]["unit"]))
# Out:
# Number of saved files: 2
# Saved files: [PosixPath('RBSP/rbspa/Processed_Mat_Files/rbspa_hope_20170701to20170731_flux_ver4.mat'), PosixPath('RBSP/rbspa/Processed_Mat_Files/rbspa_hope_20170701to20170731_xGEO_ver4.mat')]
# xGEO data keys: dict_keys(['__header__', '__version__', '__globals__', 'time', 'xGEO', 'metadata'])
# xGEO data metadata: dict_keys(['unit', 'original_cadence_seconds', 'source_files', 'description', 'processing_notes'])
# xGEO[0,:]: [-3.1846778  -4.3196673   0.15771057] RE
